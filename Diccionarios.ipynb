# %%
coche_dict = {
    "color": "Rojo",
    "marca": "Tesla",
    "modelo": "Cybertruck",
    "peso": 3500,
    "Cambio automatico": True
}
coche_dict
# Out:
# {'color': 'Rojo',
#  'marca': 'Tesla',
#  'modelo': 'Cybertruck',
#  'peso': 3500,
#  'Cambio automatico': True}

# %%
# Acceso
print(coche_dict["color"])
print(coche_dict["peso"])

#print(coche_dict["puertas"])

coche_dict["color"] = ["rojo", "gris"]
print(coche_dict)

#Añadir Element0
coche_dict["puertas"] = 6
print(coche_dict["puertas"])

# Eliminar elemento
del coche_dict["puertas"]
print(coche_dict)

#Conocer las claves del diccionario

print(coche_dict.keys())

# Conocer los valores del diccionario
print(coche_dict.values())
# Out:
# ['rojo', 'gris']
# 3500
# {'color': ['rojo', 'gris'], 'marca': 'Tesla', 'modelo': 'Cybertruck', 'peso': 3500, 'Cambio automatico': True}
# 6
# {'color': ['rojo', 'gris'], 'marca': 'Tesla', 'modelo': 'Cybertruck', 'peso': 3500, 'Cambio automatico': True}
# dict_keys(['color', 'marca', 'modelo', 'peso', 'Cambio automatico'])
# dict_values([['rojo', 'gris'], 'Tesla', 'Cybertruck', 3500, True])

# %%
# POdemos empezar tambien mediante un diccionario vacio

tienda = {}
tienda["direccion"] = "Montesa 12"
tienda["tamaños"] = 123
print(tienda)
# Out:
# {'direccion': 'Montesa 12', 'tamaños': 123}

# %%
# Errores
coche_dict["puertas"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Errores
# ----> 2 coche_dict["puertas"]
#
# KeyError: 'puertas'

# %%
numero_de_puertas = coche_dict.get ("puertas", 4)
print(numero_de_puertas)
# Out:
# 4

# %%
marca = coche_dict.get("marca", "desconocida")
print(marca)
# Out:
# Tesla

# %%
# Iterar
for i in coche_dict:
    print(i)
    print(coche_dict[i])
# Out:
# color
# ['rojo', 'gris']
# marca
# Tesla
# modelo
# Cybertruck
# peso
# 3500
# Cambio automatico
# True

# %%
for i in coche_dict:
    print(i,":",coche_dict[i])
# Out:
# color : ['rojo', 'gris']
# marca : Tesla
# modelo : Cybertruck
# peso : 3500
# Cambio automatico : True

# %%
coche_dict.items()
# Out:
# dict_items([('color', ['rojo', 'gris']), ('marca', 'Tesla'), ('modelo', 'Cybertruck'), ('peso', 3500), ('Cambio automatico', True)])

# %%
for clave,valor in coche_dict.items():
    print(clave,":",valor)
# Out:
# color : ['rojo', 'gris']
# marca : Tesla
# modelo : Cybertruck
# peso : 3500
# Cambio automatico : True
