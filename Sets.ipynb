# %%
colores= {"azul", "rojo", "verde","naranja", "azul", "verde"}
print(len(colores))
print(colores)
print(type(colores))
# Out:
# 4
# {'azul', 'rojo', 'verde', 'naranja'}
# <class 'set'>

# %%
# Añadir valores
colores.add("magenta")
print(colores)

colores.update(["celeste", "burdeos", "naranja"])
print(colores)

colores.remove("naranja")
print(colores)

for color in colores:
    print(color)
# Out:
# {'magenta', 'azul', 'celeste', 'burdeos', 'verde', 'rojo'}
# {'magenta', 'azul', 'celeste', 'burdeos', 'verde', 'rojo', 'naranja'}
# {'magenta', 'azul', 'celeste', 'burdeos', 'verde', 'rojo'}
# magenta
# azul
# celeste
# burdeos
# verde
# rojo

# %%
set1 = {1, 2, 4, 4, 2, 1, 2, 1}
set2 = {2, 1, 4}
set1 == set2
# Out:
# True

# %%
lista_con = [100,10,23,23,15,32,45,10,100,23]
print(lista_con)
#print(set(lista_con))
#print(list(set(lista_con)))
lista_con = list(set(lista_con))
print(lista_con)
# Out:
# [100, 10, 23, 23, 15, 32, 45, 10, 100, 23]
# [32, 100, 10, 45, 15, 23]
