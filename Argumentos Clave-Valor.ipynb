# %%
def insertar_movil_bd(**clave_valor):
    print(type(clave_valor))
    print(clave_valor)

insertar_movil_bd(modelo = "S20", marca = "Samsungs", camara = "24MPX",)
# Out:
# <class 'dict'>
# {'modelo': 'S20', 'marca': 'Samsungs', 'camara': '24MPX'}

# %%
def insertar_movil_bd(**kwargs):
    for clave, valor in kwargs.items():
        # insertar (clave,valor)
        print(clave, ":", valor)

insertar_movil_bd(modelo = "S20", marca = "Samsungs", camara = "24MPX", flip = True)
# Out:
# modelo : S20
# marca : Samsungs
# camara : 24MPX
# flip : True

# %%
def insertar_movil(*args, **kwargs):
    print(type(args))
    for i in args:
        print(i)

    print(type(kwargs))
    for clave, valor in kwargs.items():
        print(clave,valor)

insertar_movil("Es muy bueno", "no dura lo suficiente la bateria", \
              marca = "Samsung", modelo = "S20", precio = 1100)
# Out:
# <class 'tuple'>
# Es muy bueno
# no dura lo suficiente la bateria
# <class 'dict'>
# marca Samsung
# modelo S20
# precio 1100

# %%
def test(**kwargs, *args):
    print("test")
# Out:
#   Cell In[14], line 1
#     def test(**kwargs, *args):
#                        ^
# SyntaxError: arguments cannot follow var-keyword argument

# %%
round(12.3564, ndigits = 2)
# Out:
# 12.36

# %%
sorted([12, 3, 24, 54, 12], reverse = True)
# Out:
# [54, 24, 12, 12, 3]

# %%
def pedido_online(pedido, fecha, incidencia = False):
    if incidencia ==True:
        print("Pongase en contacto con Att. al Cliente")
    print("Su pedido de", pedido, "se entregará el ", fecha)
    
pedido_online("Televisor LG", "12/12/2026")
pedido_online("iMac 27''", "10/11/2026", incidencia = True)
# Out:
# Su pedido de Televisor LG se entregará el  12/12/2026
# Pongase en contacto con Att. al Cliente
# Su pedido de iMac 27'' se entregará el  10/11/2026

# %%
def pedido_online(pedido, incidencia = False, fecha):
    if incidencia ==True:
        print("Pongase en contacto con Att. al Cliente")
    print("Su pedido de", pedido, "se entregará el ", fecha)
# Out:
#   Cell In[21], line 1
#     def pedido_online(pedido, incidencia = False, fecha):
#                                                   ^
# SyntaxError: parameter without a default follows parameter with a default
