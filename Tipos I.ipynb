# %%
num_real = 24.69
print(type(num_real))

num_entero = int(num_real)
print(num_entero)
print(type(num_entero))
# Out:
# <class 'float'>
# 24
# <class 'int'>

# %%
# Esta función tiene dos argumentos: el número y la cantidad de decimales que queremos conservar.
# Verremos funciones más adelante.

num_real = 24.686
num_redondeado = round(num_real, 2)

# %%
print(num_redondeado)
# Out:
# 24.69

# %%
num_redondeado = 24.69
num_convertido = round(num_redondeado,0)
print(num_convertido, type(num_convertido))
# Out:
# 25.0 <class 'float'>

# %%
print(int(num_convertido))
# Out:
# 25

# %%
num_real = 24.69 
num_entero = 12

real_str = str(num_real)
entero_str = str(num_entero)

print(real_str, "su tipo ", type(real_str))
print(entero_str, "su tipo ", type(entero_str))
# Out:
# 24.69 su tipo  <class 'str'>
# 12 su tipo  <class 'str'>

# %%
print(num_real + num_entero)
print(real_str + entero_str)
# Out:
# 36.69
# 24.6912

# %%
mi_entero = 98
print(mi_entero) 
# Creo que hay un corte en el video
# Out:
# 98

# %%
mi_cadena = "98"
mi_entero = int(mi_cadena)
print(mi_cadena, type(mi_cadena))
print(mi_entero, type(mi_entero))
mi_cadena_real = "98,33"
mi_real = float(mi_cadena_real)
# Out:
# 98 <class 'str'>
# 98 <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       2 mi_entero = int(mi_cadena)
#       3 print(mi_cadena, type(mi_cadena))
#       4 print(mi_entero, type(mi_entero))
#       5 mi_cadena_real = "98,33"
# ----> 6 mi_real = float(mi_cadena_real)
#
# ValueError: could not convert string to float: '98,33'

# %%
mi_cadena_real = "98.64"
mi_real = float(mi_cadena_real)
print(mi_real, type(mi_real))
# Out:
# 98.64 <class 'float'>

# %%
booleano = bool(123)
print(booleano, type(booleano))
# Out:
# True <class 'bool'>

# %%
booleano = bool(0)
print(booleano, type(booleano))
# Out:
# False <class 'bool'>

# %%
booleano = bool("")
booleano_2 = bool("Esto es otro tipo de booleano al hacer la conversión")
print(booleano, type(booleano))
print(booleano_2, type(booleano_2))
# Out:
# False <class 'bool'>
# True <class 'bool'>

# %%
bool_str = str(booleano)
bool_2_str = str(booleano_2)
print(bool_str, bool_2_str)
# Out:
# False True

# %%
real_str = "68,34"
real = float(real_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 real_str = "68,34"
# ----> 2 real = float(real_str)
#
# ValueError: could not convert string to float: '68,34'

# %%
real_str.replace(",",".")
# Out:
# '68.34'

# %%
nuevo_str = real_str.replace(",",".")
print(type(nuevo_str))
# Out:
# <class 'str'>

# %%
real = float(nuevo_str)
print(real, type(real))
# Out:
# 68.34 <class 'float'>

# %%
primer_input = input("Escribeme argo mi arma")
# Out:
# Escribeme argo mi arma 98

# %%
print(primer_input)
# Out:
# 98

# %%
type(primer_input)
# Out:
# str

# %%
nombre = input("¿Cómo te llamas alma cándida de Dios?")
print("Encantado de conocerte,",nombre)
preferencias = input("Y, ¿qué te parece este magnífico vídeo?")
print("Coincido")
# Out:
# ¿Cómo te llamas alma cándida de Dios? Alejandro
# Encantado de conocerte, Alejandro
# Y, ¿qué te parece este magnífico vídeo? Aburridísimo
# Coincido

# %%
print(None)
# Out:
# None

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
"" == None
# Out:
# False

# %%
0 == None
# Out:
# False

# %%
False == None
# Out:
# False

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
