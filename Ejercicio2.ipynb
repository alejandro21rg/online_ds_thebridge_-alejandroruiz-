# %% [markdown]
# # Markdown (II)

# %% [markdown]
# "En un lugar de la Mancha"
# "Veinte años después frente al pelotón de fusilamiento"

# %% [markdown]
# "En un lugar de la Mancha"
# "Veinte años después frente al pelotón de fusilamiento"

# %% [markdown]
# # Primer apartado

# %% [markdown]
# 1. Primer elemento
# 2. Segundo elemento

# %% [markdown]
# * Elemento 1
# * Elemento 2
# - Elemento 3
# + Elemento 4

# %% [markdown]
# ```Python
# variable = "Esto es una variable"
# ```

# %% [markdown]
# ***
# ---

# %% [markdown]
# Para `crear enlaces externos`, a páginas web, se usa
# [enlace con texto cambiado] (https://www.google.com/)
# Si haces click [este enlace](#Markdown-(II)). Para ir al primer apartado [este otro enlace](#Primer-apartado).

# %% [markdown]
# ![esta en el mismo directorio](./error.png)
# ![este es un ejemplo de imagen que no esta en mi directorio](./img/error.png)

# %% [markdown]
# <img src="./img/error.png" width = 800>
