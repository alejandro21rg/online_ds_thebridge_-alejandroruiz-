# %%
ingresos = 1000
gastos = 100
beneficios = ingresos - gastos

# %%
print(ingresos)
print(gastos)
print("Los beneficios han sido de :")
print(beneficios)
# Out:
# 1000
# 100
# Los beneficios han sido de :
# 900

# %%
mes = "junio"
print("Los beneficios de %s han sido %s millones" %(mes, beneficios) )
# Out:
# Los beneficios de junio han sido 900 millones

# %%
print("Los beneficios de %s han sido %s millones" %(beneficios, mes) )
# Out:
# Los beneficios de 900 han sido junio millones

# %%
mes = "agosto"
print("Los beneficios de", mes, "han sido", beneficios, "millones")
# Out:
# Los beneficios de agosto han sido 900 millones

# %%
# Comentario de línea 
# print("Esto lo ignora")
print("Esto sí lo ejecutará")
# Out:
# Esto sí lo ejecutará

# %%
print("Fin del programa") # Esta línea indica que hemos terminado
# Out:
# Fin del programa

# %%
'''
Comentario multilinea
Puedo usar varias líneas sin repetir el #
'''

"""
Los comentarios multilíneas puede ir 
entre comillas dobles, y tanpoco se ejecutan o interpretan este
print("No se va a ejecutar")
"""
print("Este print si se va a ejecutar")
# Out:
# Este print si se va a ejecutar

# %%
ventas_jun_jul = ventas_junio + ventas_julio
ventas_junio = 100
ventas_julio = 150
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ventas_jun_jul = ventas_junio + ventas_julio
#       2 ventas_junio = 100
#       3 ventas_julio = 150
#
# NameError: name 'ventas_junio' is not defined

# %%
ventas_junio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ventas_junio
#
# NameError: name 'ventas_junio' is not defined

# %%
ventas_junio = 100
ventas_julio = 150
ventas_jun_jul = ventas_junio + ventas_julio

# %%
print("Las ventas de junio a julio son", ventas_jun_jul)
# Out:
# Las ventas de junio a julio son 250

# %%
altura = 1.80; peso = 75
print(altura, peso)
# Out:
# 1.8 75

# %%
x,y,z = 12,23,45

# %%
x = 12
y = 23
z = 45

# %%
altura = 1,85
del alturaa
print(altura)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 altura = 1,85
# ----> 2 del alturaa
#       3 print(altura)
#
# NameError: name 'alturaa' is not defined
